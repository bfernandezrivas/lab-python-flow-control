# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:

# %% [markdown]
# 1. Look at your code from the lab data structures, and improve repeated code with loops.

# %%
product = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {}

for item in product: 
    quantity = int(input(f"how many {item} I have ?"))
    inventory [item] = quantity

print (inventory)
# Out:
# {'t-shirt': 7, 'mug': 9, 'hat': 67, 'book': 90, 'keychain': 3}

# %% [markdown]
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.

# %%
customer_order = set()

while True:
    item = input("What product you want to order (t-shirt, mug, hat, book, keychain)? ")
    if item in product:
        customer_order.add(item)
        print (f'{item}', "added to your order")
    else:
        print(f'{item}' " is not a product available")
    
    more_items = input ("want to add another product? (yes/no)")
    if more_items != "yes":
       break

print ("products ordered:")   
print (customer_order)
# Out:
# mug added to your order
# iguana is not a product available
# book added to your order
# hat added to your order
# products ordered:
# {'book', 'hat', 'mug'}

# %% [markdown]
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
for item in customer_order:
    if item in inventory:
        if inventory[item]>0:
           inventory[item] -= 1
           print (f'{item}',"uptaded now there's",{inventory[item]},"left in inventory")
        else:
           print (f'{item}', "is out of stock in inventory")
    else:
        print (f'{item}', "does not exist in inventory")    

print ("updated inventory:")
print (inventory)
# Out:
# book uptaded now there's {89} left in inventory
# hat uptaded now there's {66} left in inventory
# mug uptaded now there's {8} left in inventory
# updated inventory:
# {'t-shirt': 7, 'mug': 8, 'hat': 66, 'book': 89, 'keychain': 3}
